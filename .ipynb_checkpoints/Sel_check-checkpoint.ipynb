# %%
import h5py
import pandas as pd

# %%
filename = "no_pairing/m2_peak/selection_pe_samples/Trimmed_Selection_File.h5"

with h5py.File(filename, "r") as f:
    inj_group = f["injections"]
    
    data = {
        key: inj_group[key][()]
        for key in inj_group.keys()
    }

df = pd.DataFrame(data)

# %%
df.columns
# Out:
# Index(['chi_eff', 'dluminosity_distance_dredshift', 'estimated_optimal_snr_H',
#        'estimated_optimal_snr_L', 'estimated_optimal_snr_V',
#        'estimated_optimal_snr_net', 'inclination', 'lnpdraw_inclination',
#        'lnpdraw_mass1_source_mass2_source_redshift_spin1x_spin1y_spin1z_spin2x_spin2y_spin2z',
#        'luminosity_distance', 'mass1_source', 'mass2_source', 'mass_1',
#        'o3_cwb_far', 'o3_cwb_p_astro', 'o3_cwb_ranking_statistic',
#        'o3_gstlal_far', 'o3_gstlal_p_astro', 'o3_mbta_far', 'o3_mbta_p_astro',
#        'o3_mbta_ranking_statistic', 'o3_pycbc_bbh_far', 'o3_pycbc_bbh_p_astro',
#        'o3_pycbc_bbh_ranking_statistic', 'o3_pycbc_hyperbank_far',
#        'o3_pycbc_hyperbank_p_astro', 'o3_pycbc_hyperbank_ranking_statistic',
#        'o4a_cwb-bbh_far', 'o4a_cwb-bbh_p_astro',
#        'o4a_cwb-bbh_ranking_statistic', 'o4a_gstlal_far', 'o4a_gstlal_p_astro',
#        'o4a_gstlal_ranking_statistic', 'o4a_mbta_far', 'o4a_mbta_p_astro',
# ...

# %%
df
# Out:
#          chi_eff  dluminosity_distance_dredshift  estimated_optimal_snr_H  \
# 0       0.088344                     5355.347964                11.417947
# 1       0.043996                     5107.971125                12.865807
# 2       0.092485                     5543.038981                 9.683957
# 3       0.472000                     5800.383257                11.717487
# 4      -0.077633                     5323.210519                 9.603431
# ...          ...                             ...                      ...
# 606119 -0.179191                     5884.083413                 9.850641
# 606120  0.657256                     5620.911045                12.748122
# 606121 -0.106903                     5180.191910                15.997637
# 606122  0.898256                     6530.136016                11.756732
# 606123  0.130711                     7729.407729                15.275697
#
#         estimated_optimal_snr_L  estimated_optimal_snr_V  \
# ...
